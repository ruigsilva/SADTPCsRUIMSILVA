# %% [markdown]
# SAD_TPC_02_RuiMSilva
#
# # Trabalho efectuado por : Rui Guilherme M Silva
# # Aluno nº 19901535
# # Informática de Gestão
#
# #INTRODUÇÃO
#
#   Neste TPC02 o desafio continua de aprofundar o conhecimento da linguagem Python, que apesar de ter aprendido C,C++ há 24 anos atrás a minha profissão,  principalmente nos últimos 18 anos na Intel, não passou por programador, mas sim na área técnica, comercial e marketing de soluções TI.
#
#   Posto isto achei interessante partilhar com o Prof Nuno como progredi neste trabalho dado que no TPC01 já só apresentei o resultado final, já a funcionar, depois de umas boas horas em volta do Python..
#   Apesar da quantidade imensa de recursos disponíveis na internet, a grande questão está em encontrar um bom fio condutor de aprendizagem que permita evoluir nessa senda.
#
#   Como referi no ínicio, aprendi C (e PASCAL) , há 24 anos, na UAL por sinal :) ,  em Introdução á Programação que era uma cadeira anual, quando as licenciaturas eram de 4 anos..    Na altura cheguei ao 4º ano sem contudo completar pois faltam-me as Análises Matemáicas I,II e III apesar de ter feito Algebra Linear, Sistemas Digitais, Computação Gráfica e um série de outras...    Quando retornei no ano passado à Universidade mudei para Informática de Gestão pois era mais na linha do meu desenvolvimento profissional...   e aqui estou com 7 cadeiras este semestre (POO,Est, CG, e as do 3º Ano excepto Redes que já tenho creditada) o que constitui um desafio enorme em termos de planeamento de estudo para cadeiras como esta de SAD a qual gostava de ainda poder dedicar mais tempo...
#
#   Posto isto vamos ao que interessa..  :-)  relativamente ao TPC02
#
# #TPC02
#
#   Prof, se estiver com pouco tempo pode saltar para o final onde encontra a tentativa nº3 - bem sucedida!
#
#   Optei por colocar aqui algumas das explorações que chegeui a fazer depois de pensar na estratégia (várias) para trabalhar um baralho de cartas (deck) e como comparar um full 52 deck com uma lista qualquer...   {o resultado final surgiu após uma série de horas  dividas entre Sábado e Domingo dado que com 3 filhos e mulher..  tenho que conseguir o meu canto sossegado para explorar a programação..}
#
#   Assim numa primeira abordagem cheguei a pensar usar como base a seguinte definição de baralho, com naipes e ordem  (suits, ranks) e converter as respectivas para a forma abreviada As para A, Diamonds para O,  Clubs para P (Paus), etc...
#
#   import random
#
#
# def cria_baralho():
#     """Retorna uma lista de um baralho de 52 cartas."""
#     naipes = ["E", "C", "O", "P"]
#     ordem = ["2", "3", "4", "5", "6", "7", "8", "9", "T",
#              "J", "Q", "K", "A"]
#     baralho = []
#     for s in naipes:
#         for r in ordem:
#             name = "%s%s" % (r, s)
#             baralho.append(name)
#     return baralho
#
# def tira_carta(baralho):
#     """ Tira uma carta ao calhas do baralho."""
#     n = len(baralho)
#     i = random.randint(0, n-1)  #importante para permitir que gere o number
#     k = escolhe_carta(baralho, i)
#     return k
#
# def escolhe_carta(baralho, x):
#     """Retorna carta no. x do baralho"""
#     return baralho[x]
#
# print()
# print("Cria baralho de 52 cartas :")
# print()
# baralho = cria_baralho()  #atribui à variável baralho o baralho gerado por cria_baralho()
# print(baralho)
#
# """print ("Tira carta do baralho ")
# carta = tira_carta()
# print (carta) """
#
# monte = ['2E','5O']
#
# (...)
#
#      # Acabei por abandonar esta definição base pois nesta altura ainda não tinha o conhecimento das funções e mecânica de manipular as listas de tuplos..

# %%
import random

# Tentativa #01 (TPC02 ) não terminada
 
def cria_baralho():
    """Retorna uma lista de um baralho de 52 cartas."""
    naipes = ["E", "C", "O", "P"]
    ordem = ["2", "3", "4", "5", "6", "7", "8", "9", "T",
             "J", "Q", "K", "A"]
    baralho = []
    for s in naipes:
        for r in ordem:
            name = "%s%s" % (r, s)
            baralho.append(name)
    return baralho

def tira_carta(baralho):
    """ Tira uma carta ao calhas do baralho."""
    n = len(baralho)
    i = random.randint(0, n-1)  #importante para permitir que gere o number
    k = escolhe_carta(baralho, i)
    return k

def escolhe_carta(baralho, x):
    """Retorna carta no. x do baralho"""
    return baralho[x]

print()
print("Cria baralho de 52 cartas :")
print()
baralho = cria_baralho()  #atribui à variável baralho o baralho gerado por cria_baralho()
print(baralho)

"""print ("Tira carta do baralho ")
carta = tira_carta()
print (carta) """

monte = ['2E','5O']
# Out:
# Cria baralho de 52 cartas :
#
# ['2E', '3E', '4E', '5E', '6E', '7E', '8E', '9E', 'TE', 'JE', 'QE', 'KE', 'AE', '2C', '3C', '4C', '5C', '6C', '7C', '8C', '9C', 'TC', 'JC', 'QC', 'KC', 'AC', '2O', '3O', '4O', '5O', '6O', '7O', '8O', '9O', 'TO', 'JO', 'QO', 'KO', 'AO', '2P', '3P', '4P', '5P', '6P', '7P', '8P', '9P', 'TP', 'JP', 'QP', 'KP', 'AP']

# %% [markdown]
# # Tentativa 2 - TPC02.
#
# # Quando explorava as funções embutidas e algumas das bibliotecas descobri que havia uma série de funções que poderiam facilitar a respectiva manipulação sendo que cheguei a ter as seguintes funções/métodos das quais conseguir ter algumas funcionalidades.. estas baseadas no pydealer...    Mais uma vez após um par de horas achei que estaria num caminho de exploração que não me ajudaria a simplicar o que era necessário..
#
#
# import pydealer
#
# from pydealer import (
#         Card,
#         Deck,
#         Stack
# )
#
# from pydealer.utils import(
#         build_cards,
#         compare_stacks,
#         check_sorted
# )
#
# # construir um baralho
# deck = pydealer.Deck()
#
# deck = pydealer.Decks(ranks=POKER_RANKS)
#
# deck.ranks = POKER_RANKS
#
# # Construir um baralho padrão de 52 cartas
# deck = pydealer.DECK(rebuild=True)
#
# # Para baralhar o baralho construido
# deck = pydealer.Deck(rebuild=True, re_shuffle=True)
#
# # constroi um baralho vazio
# hand = pydealer.Stack()
#
# # suffle um stack/deck
# deck = pydealer.Deck()
#
#
# #Sort a Stack/Deck
# deck = pydealer.Deck()
# deck.sort()
#
# # construir uam lista de termos de procura
# terms = ["Ace of Spades", "QH","2","Clubs"]
#
# indices = deck.find_list(terms)
#
# # o mesmo que usar len(deck)
# de_size = deck.size
#
# # comparar 2 decks
#
# deck_x = pydealer.Deck()
# deck_y = pydealer.Deck()
#
# result = compare_stacks(deck_x, deck_y)
#
#
# # Define uma nova ordem, ``new_ranks``,  usando apenas a númeração.
# new_ranks = {
#     "values": {
#         "Ace": 13,
#         "King": 12,
#         "Queen": 11,
#         "Jack": 10,
#         "10": 9,
#         "9": 8,
#         "8": 7,
#         "7": 6,
#         "6": 5,
#         "5": 4,
#         "4": 3,
#         "3": 2,
#         "2": 1
#     }
# }
#
# # Define o set de naipes com atraibuição numérica
# new_ranks = {
#     "suits": {
#         "Spades": 4,
#         "Hearts": 3,
#         "Clubs": 2,
#         "Diamonds": 1
#     }
# }
#
# # Define  a nova ordenação com ambos os naipes e as cartas.
# new_ranks = {
#     "values": {
#         "Ace": 13,
#         "King": 12,
#         "Queen": 11,
#         "Jack": 10,
#         "10": 9,
#         "9": 8,
#         "8": 7,
#         "7": 6,
#         "6": 5,
#         "5": 4,
#         "4": 3,
#         "3": 2,
#         "2": 1
#     },
#     "suits": {
#         "Spades": 4,
#         "Hearts": 3,
#         "Clubs": 2,
#         "Diamonds": 1
#     }
# }

# %% [markdown]
# # Tentativa 3 do TPC02 -   bem sucedida !!
#
# Nesta última abordagem ao consultar alguns colegas acabei por aprender que haviam formas muito mais simples de abordar o problema proposto e com funções elementares...  Apesar de que a exploração foi enriquecedora e que poderá ser útil para outros trabalhos acabei por encontrar uma forma bem mais simplificada de encontrar a solução pretendida ao desafio proposto.

# %%
"""
Created on Mon Oct 29 22:12:01 2018

@author: Rui Guilherme Silva
            19901535 
            Informática de Gestão
"""

""" Criação da função que permite obter uma comparação de uma lista definida como baralho_completo
     em baixo discriminada com LISTA_A e LISTA_B para testar o algoritmo de comparação
"""

def deckSolutions(lista_de_cartas):

    # Criação do dicionário que representa um baralho completo de 52 cartas
    # Atribuída as notações do enunciado como 1C = Ás de Copas, ...
    # é atribuido o valor 0 que será usado para a comparação no ciclo com incrementação 
    # que encontre carta igual
    baralho_completo = {"1C":0, "2C":0, "3C":0, "4C":0, "5C":0, "6C":0, 
                        "7C":0, "8C":0, "9C":0, "10C":0, "DC":0, "VC":0, 
                        "RC":0, "1P":0, "2P":0, "3P":0, "4P":0, "5P":0,
                        "6P":0, "7P":0, "8P":0, "9P":0, "10P":0, "DP":0,
                        "VP":0, "RP":0, "1O":0, "2O":0, "3O":0, "4O":0, 
                        "5O":0, "6O":0, "7O":0, "8O":0, "9O":0, "10O":0, 
                        "DO":0, "VO":0, "RO":0,"1E":0, "2E":0, "3E":0,
                        "4E":0, "5E":0, "6E":0, "7E":0, "8E":0, "9E":0,
                        "10E":0, "DE":0, "VE":0, "RE":0}
    
    # define cartas como baralho contendo todas as cartas 
    cartas = baralho_completo.keys()
    
    # ciclo for que irá ler cada carta na lista de cartas obtida 
    for carta in lista_de_cartas:
        
        # Se a carta lida estiver no baralho 
        if carta in cartas:
    
        # adiciona uma carta 
           baralho_completo[carta] += 1


    # Contem a lista de todos os valores que corresponde ao números de cartas de cada um
    Numeros_Lista_Cartas = baralho_completo.values()
    
    # define resultado com quantos baralhos completos estão contados
    resultado = min(Numeros_Lista_Cartas)
    
    # Imprime o resultado de cada lista apresentada 
    print("o nº de baralhos completos de 52 cartas é:")
    print(resultado)
    

  # exemplo de uma lista com algumas cartas correspondendo a zero baralhos completos
LISTA_A = ["1P", "1C", "1O", "2P"]  

 # exemplo de uma lista dada no enunciado com cartas suficientes
# para formar  2 baralhos completos...
LISTA_B = ["1P", "1C", "1O", "2P", "2C", "2O", "2E", "3P", "3C", "3O", 
           "3E", "4P", "4C", "4O", "4E", "5P", "5C", "5O", "5E", "6P",
           "6C", "6O", "6E", "7P", "7C", "7O", "7E", "8P", "8C", "8O",
           "8E", "9P",  "9C", "9O",  "9E", "DP","DC", "DO", "DE", "JP", 
           "JE", "VP", "VC", "VO","VE", "RP", "RC", "RO", "RE", "1P", 
           "1C", "1O", "1E", "2P", "2C", "2O", "2E", "3P", "3C", "3O", 
           "3E", "4P", "4C", "4O", "4E", "5P","5C", "5O", "5E", "6P", 
           "6C", "6O", "6E", "7P", "7C", "7O", "7E", "8P", "8C", "8O",
           "8E", "9P", "9C", "9O", "9E", "DP", "DC", "DO", "DE", "JP", 
           "JC", "JO","JE", "VP", "VC", "VO", "VE", "RP", "RC", "RO", 
           "RE", "1P", "1C", "1O", "1E", "2P", "2C", "2O", "2E", "3P",
           "3C", "3O", "3E", "4P", "4C", "4O", "4E",  "5P", "5C", "5O", 
           "5E", "6P", "6C", "6O", "6E", "7P", "7C", "7O", "7E", "8P", 
           "8C", "8O", "8E", "9P", "9C", "9O", "9E", "DP", "DC", "DO", 
           "DE", "JP", "JC", "JO", "JE", "VP", "VC", "VO", "VE", "RP",
           "RC", "RO", "RE", "10C", "10P", "10O", "10E", "10C", "10P",
           "10O", "10E", "10C", "10P", "10O", "10E", "1E" "JC", "JO"]

#esta lista contem zero baralhos completos
LISTA_C = ["3E", "4P", "4C", "4O", "4E", "5P", "5C", "5O", "5E", "6P", "6C", "6O", 
     "6E", "7P", "7C", "7O", "7E", "8P", "8C", "8O", "8E", "9P", "9C", "9O", "9E", "DP", 
     "DC", "DO", "DE", "JP", "JC", "JO", "JE", "VP", "VC", "VO", "VE", "RP", "RC", "RO", "RE", 
     "1P", "1C", "1O", "1E", "2P", "2C", "2O", "2E", "3P", "3C", "3O", "3E", 
     "4P", "4C", "4O", "4E", "5P", "5C", "5O", "5E", "6P", "6C", "6O", "6E", "7P", "7C", 
     "7O", "7E", "8P", "8C", "8O", "8E", "9P", "9C", "9O", "9E", "DP", "DC", "DO", "DE", 
     "JP", "JC", "JO", "JE", "VP", "VC", "VO", "VE", "RP", "RC", "RO", "RE", "1P", "1C", 
     "1O", "1E", "2P", "2C", "2O", "2E", "3P", "3C", "3O", "3E", "4P", "4C", "4O", "4E", 
     "5P", "5C", "5O", "5E", "6P", "6C", "6O", "6E", "7P", "7C", "7O", "7E", "8P", "8C", 
     "8O", "8E", "9P", "9C", "9O", "9E", "DP", "DC", "DO", "DE", "JP", "JC", "JO", "JE", 
     "VP", "VC", "VO", "VE", "RP", "RC", "RO", "RE"] 

#Esta lista contem 1 baralho completo
LISTA_D = ["3E", "4P", "4C", "4O", "4E", "5P", "5C", "5O", "5E", "6P", "6C", "6O", 
     "6E", "7P", "7C", "7O", "7E", "8P", "8C", "8O", "8E", "9P", "9C", "9O", "9E", "DP", 
     "DC", "DO", "DE", "JP", "JC", "JO", "JE", "VP", "VC", "VO", "VE", "RP", "RC", "RO", "RE", 
     "1P", "1C", "1O", "1E", "2P", "2C", "2O", "2E", "3P", "3C", "3O", "3E", 
     "4P", "4C", "4O", "4E", "5P", "5C", "5O", "5E", "6P", "6C", "6O", "6E", "7P", "7C", 
     "7O", "7E", "8P", "8C", "8O", "8E", "9P", "9C", "9O", "9E", "DP", "DC", "DO", "DE", 
     "JP", "JC", "JO", "JE", "VP", "VC", "VO", "VE", "RP", "RC", "RO", "RE", "1P", "1C", 
     "1O", "1E", "2P", "2C", "2O", "2E", "3P", "3C", "3O", "3E", "4P", "4C", "4O", "4E", 
     "5P", "5C", "5O", "5E", "6P", "6C", "6O", "6E", "7P", "7C", "7O", "7E", "8P", "8C", 
     "8O", "8E", "9P", "9C", "9O", "9E", "DP", "DC", "DO", "DE", "JP", "JC", "JO", "JE", 
     "VP", "VC", "VO", "VE", "RP", "RC", "RO", "RE","10P","10O","10C","10E"] 

# Esta lista contem 3 baralhos completos...
LISTA_E =["1P", "1C", "1O", "2P", "2C", "2O", "2E", "3P", "3C", "3O", 
     "3E", "4P", "4C", "4O", "4E", "5P", "5C", "5O", "5E", "6P", "6C", 
     "6O", "6E", "7P", "7C", "7O", "7E", "8P", "8C", "8O", "8E", "9P", "9C", "9O", 
     "9E", "DP", "DC", "DO", "DE", "JP", "JC", "JO", "JE", "VP", "VC", "VO", 
     "VE", "RP", "RC", "RO", "RE", "1P", "1C", "1O", "1E", "2P", "2C", "2O", 
     "2E", "3P", "3C", "3O", "3E", "4P", "4C", "4O", "4E", "5P", "5C", "5O", "5E",
     "6P", "6C", "6O", "6E", "7P", "7C", "7O", "7E", "8P", "8C", "8O", "8E", "9P", 
     "9C", "9O", "9E", "DP", "DC", "DO", "DE",  "JP", "JC", "JO", "JE", "VP", "VC",
     "VO", "VE", "RP", "RC", "RO", "RE", "1P", "1C",  "1O", "1E", "2P", "2C", "2O",
     "2E", "3P", "3C", "3O", "3E", "4P", "4C", "4O", "4E", 
     "5P", "5C", "5O", "5E", "6P", "6C", "6O", "6E", "7P", 
     "7C", "7O", "7E", "8P", "8C", 
     "8O", "8E", "9P", "9C", "9O", "9E", "DP", "DC",
     "DO", "DE", "JP", "JC", "JO", "JE", 
     "VP", "VC", "VO", "VE", "RP", "RC", "RO", "RE",
     "10C", "10P", "10O", "10E", "10C", "10P", "10O", 
     "10E", "10C", "10P", "10O", "10E", "1E"]


deckSolutions(LISTA_A)
print()

deckSolutions(LISTA_B)
print()

deckSolutions(LISTA_C)
print()

deckSolutions(LISTA_D)
print()

deckSolutions(LISTA_E)
# Out:
# o nº de baralhos completos de 52 cartas é:
# 0
#
# o nº de baralhos completos de 52 cartas é:
# 2
#
# o nº de baralhos completos de 52 cartas é:
# 0
#
# o nº de baralhos completos de 52 cartas é:
# 1
#
# o nº de baralhos completos de 52 cartas é:
# 3
